# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
import scipy.stats
import statsmodels.formula.api as smf
import statsmodels.api as sm
import urllib
import requests
import zipfile
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)
from sklearn.decomposition import PCA
import geopandas as gpd
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from fiona.crs import from_epsg
import os
from astropy.stats import median_absolute_deviation
from sklearn.decomposition import FactorAnalysis
from sklearn.model_selection import cross_val_score
from factor_analyzer import FactorAnalyzer
from sklearn import  preprocessing
import pysal
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('DATA/BKtotal.csv')

# %%
data.head()
# Out:
#    Unnamed: 0        GEOID  pickups_intract  NYPDviolation  NYPDmisdemeanor  \
# 0           1  36047000100     102138.80700           19.0             37.0
# 1           2  36047000200      21497.86679           20.0            125.0
# 2           3  36047000301      96582.50072           10.0             56.0
# 3           4  36047000501      39175.79425            8.0             25.0
# 4           5  36047000502      45341.36746           19.0             63.0
#
#    NYPDfelony  units        BBLE_x    CUR_FV_T_x    GR_SQFT_x    NEW_FV_T_x  \
# 0        26.0  106.0  3.002170e+09  3.475541e+06  3082.633028  4.153486e+06
# 1        84.0    NaN  3.007315e+09  4.646324e+05  2101.235294  5.933824e+05
# 2        46.0    NaN           NaN           NaN          NaN           NaN
# 3        17.0   62.0           NaN           NaN          NaN           NaN
# 4        38.0    NaN  3.002448e+09  4.662071e+06  3940.821429  5.191607e+06
#
#    CUR_FV_T_perSQFT_x  NEW_FV_T_perSQFT_x        BBLE_y    CUR_FV_T_y  \
# 0         1190.616338         1459.290687  3.002164e+09  4.638009e+06
# 1          243.786509          313.939797  3.007247e+09  6.890158e+05
# 2                 NaN                 NaN           NaN           NaN
# 3                 NaN                 NaN           NaN           NaN
# 4         1317.588974         1528.943303  3.002444e+09  3.929388e+06
#
#      GR_SQFT_y    NEW_FV_T_y  CUR_FV_T_perSQFT_y  NEW_FV_T_perSQFT_y  \
# 0  48916.53846  5.724470e+06         1363.877877         1585.105886
# 1  10987.54211  7.652978e+05          305.963908          367.481876
# 2          NaN           NaN                 NaN                 NaN
# 3          NaN           NaN                 NaN                 NaN
# 4  23729.72727  4.238306e+06          989.028877         1184.871247
#
#    Median_house_Value  Median_Rent  Housing_Units  Total_pop    Pop_Den  \
# 0            694900.0       1434.0         2446.0     4304.0   49889.94
# 1            462500.0       1344.0          449.0     1868.0   16619.20
# 2            682600.0       1955.0         2275.0     3985.0   48017.63
# 3            721900.0       1853.0         2024.0     4759.0  147218.90
# 4            517200.0       1979.0         1675.0     2600.0   69557.17
#
#    Median_Household_Income  Ratio_income_to_poverty_level_under_2  Gini_Index  \
# 0                  70938.0                                  928.0      0.5568
# 1                  34740.0                                 1245.0      0.4267
# 2                 101544.0                                 1035.0      0.5830
# 3                 110700.0                                  551.0      0.5084
# 4                  91964.0                                  353.0      0.5410
#
#    Ave_Commute_Min  Dropout_16_19  Bachelor_up_25_64  Unemployed_rate_16  \
# 0             33.0        0.00000           0.666306            0.041451
# 1             38.0        0.00000           0.042871            0.079075
# 2             31.0        0.00000           0.681919            0.030144
# 3             30.0        0.00000           0.856592            0.070352
# 4             30.0        0.12766           0.865585            0.078696
#
#    Occupied_Housing_Units_2015_  Occupied_Housing_Units_2010_2014  \
# 0                      0.024514                          0.243293
# 1                      0.000000                          0.254157
# 2                      0.017214                          0.302313
# 3                      0.004449                          0.365406
# 4                      0.008844                          0.295918
#
#    Occupied_Housing_Units_2010_before     Black     White     Asian
# 0                            0.732192  0.109898  0.740474  0.058086
# 1                            0.745843  0.101713  0.247323  0.004818
# 2                            0.680473  0.036637  0.830364  0.046675
# 3                            0.630145  0.075436  0.743223  0.098340
# 4                            0.695238  0.036923  0.816923  0.097692

# %%
data.units = data.units.replace(np.nan,0)

# %%
data = data.drop(['Unnamed: 0','BBLE_x','BBLE_y','Black','White','Asian'],axis=1)

# %%
data.head(3)
# Out:
#          GEOID  pickups_intract  NYPDviolation  NYPDmisdemeanor  NYPDfelony  \
# 0  36047000100     102138.80700           19.0             37.0        26.0
# 1  36047000200      21497.86679           20.0            125.0        84.0
# 2  36047000301      96582.50072           10.0             56.0        46.0
#
#    units    CUR_FV_T_x    GR_SQFT_x    NEW_FV_T_x  CUR_FV_T_perSQFT_x  \
# 0  106.0  3.475541e+06  3082.633028  4.153486e+06         1190.616338
# 1    0.0  4.646324e+05  2101.235294  5.933824e+05          243.786509
# 2    0.0           NaN          NaN           NaN                 NaN
#
#    NEW_FV_T_perSQFT_x    CUR_FV_T_y    GR_SQFT_y    NEW_FV_T_y  \
# 0         1459.290687  4.638009e+06  48916.53846  5.724470e+06
# 1          313.939797  6.890158e+05  10987.54211  7.652978e+05
# 2                 NaN           NaN          NaN           NaN
#
#    CUR_FV_T_perSQFT_y  NEW_FV_T_perSQFT_y  Median_house_Value  Median_Rent  \
# 0         1363.877877         1585.105886            694900.0       1434.0
# 1          305.963908          367.481876            462500.0       1344.0
# 2                 NaN                 NaN            682600.0       1955.0
#
#    Housing_Units  Total_pop   Pop_Den  Median_Household_Income  \
# 0         2446.0     4304.0  49889.94                  70938.0
# 1          449.0     1868.0  16619.20                  34740.0
# 2         2275.0     3985.0  48017.63                 101544.0
#
#    Ratio_income_to_poverty_level_under_2  Gini_Index  Ave_Commute_Min  \
# 0                                  928.0      0.5568             33.0
# 1                                 1245.0      0.4267             38.0
# 2                                 1035.0      0.5830             31.0
#
#    Dropout_16_19  Bachelor_up_25_64  Unemployed_rate_16  \
# 0            0.0           0.666306            0.041451
# 1            0.0           0.042871            0.079075
# 2            0.0           0.681919            0.030144
#
#    Occupied_Housing_Units_2015_  Occupied_Housing_Units_2010_2014  \
# 0                      0.024514                          0.243293
# 1                      0.000000                          0.254157
# 2                      0.017214                          0.302313
#
#    Occupied_Housing_Units_2010_before
# 0                            0.732192
# 1                            0.745843
# 2                            0.680473

# %%
TRACT = gpd.GeoDataFrame.from_file('DATA/gz_2010_36_140_00_500k/gz_2010_36_140_00_500k.shp')

# %%
TRACT.GEO_ID = TRACT.GEO_ID.str[9:]

# %%
data.GEOID = data.GEOID.astype('str')

# %%
data = pd.merge(TRACT,data,left_on='GEO_ID',right_on='GEOID')

# %%
data.TRACT = data.TRACT.astype('int64')

# %%
NTA = pd.read_csv('DATA/2010CensusTract_PUMA_NTA(1).csv')

# %%
NTA = NTA[NTA['Borough'] == 'Brooklyn']

# %%
data = pd.merge(data,NTA,left_on='TRACT',right_on='2010CensusTract')

# %%
data.groupby('PUMA').median()['pickups_intract'][4001]
# Out:
# 45895.610660000006

# %%
def median_interpolation(data,columns):
    for column in columns:
        for i in range(len(data.index)):
            if np.isnan(data[column][i]):
                data[column][i] = data.groupby('PUMA').median()[column][data['PUMA'][i]] 
    return data

# %%
data.columns[9:39]
# Out:
# Index(['pickups_intract', 'NYPDviolation', 'NYPDmisdemeanor', 'NYPDfelony',
#        'units', 'CUR_FV_T_x', 'GR_SQFT_x', 'NEW_FV_T_x', 'CUR_FV_T_perSQFT_x',
#        'NEW_FV_T_perSQFT_x', 'CUR_FV_T_y', 'GR_SQFT_y', 'NEW_FV_T_y',
#        'CUR_FV_T_perSQFT_y', 'NEW_FV_T_perSQFT_y', 'Median_house_Value',
#        'Median_Rent', 'Housing_Units', 'Total_pop', 'Pop_Den',
#        'Median_Household_Income', 'Ratio_income_to_poverty_level_under_2',
#        'Gini_Index', 'Ave_Commute_Min', 'Dropout_16_19', 'Bachelor_up_25_64',
#        'Unemployed_rate_16', 'Occupied_Housing_Units_2015_',
#        'Occupied_Housing_Units_2010_2014',
#        'Occupied_Housing_Units_2010_before'],
#       dtype='object')

# %%
data = median_interpolation(data,data.columns[9:39])
# Out:
# C:\Users\sddz0\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data.isnull().sum()
# Out:
# GEO_ID                                   0
# STATE                                    0
# COUNTY                                   0
# TRACT                                    0
# NAME                                     0
# LSAD                                     0
# CENSUSAREA                               0
# geometry                                 0
# GEOID                                    0
# pickups_intract                          0
# NYPDviolation                            0
# NYPDmisdemeanor                          0
# NYPDfelony                               0
# units                                    0
# CUR_FV_T_x                               0
# GR_SQFT_x                                0
# NEW_FV_T_x                               0
# CUR_FV_T_perSQFT_x                       0
# NEW_FV_T_perSQFT_x                       0
# CUR_FV_T_y                               0
# GR_SQFT_y                                0
# NEW_FV_T_y                               0
# CUR_FV_T_perSQFT_y                       0
# NEW_FV_T_perSQFT_y                       0
# Median_house_Value                       0
# Median_Rent                              0
# Housing_Units                            0
# Total_pop                                0
# Pop_Den                                  0
# Median_Household_Income                  0
# Ratio_income_to_poverty_level_under_2    0
# Gini_Index                               0
# Ave_Commute_Min                          0
# Dropout_16_19                            0
# Bachelor_up_25_64                        0
# Unemployed_rate_16                       0
# Occupied_Housing_Units_2015_             0
# Occupied_Housing_Units_2010_2014         0
# Occupied_Housing_Units_2010_before       0
# Borough                                  0
# 2010CensusTract                          0
# PUMA                                     0
# NTA_Code                                 0
# NTA_Name                                 0
# dtype: int64

# %%
data['units'] = (data['units']*1.0/data['Housing_Units']).fillna(0)

# %%
data = data.drop(['Housing_Units'],axis=1)

# %% [markdown]
# ## Normalization

# %%
data.columns[9:38]
# Out:
# Index(['pickups_intract', 'NYPDviolation', 'NYPDmisdemeanor', 'NYPDfelony',
#        'units', 'CUR_FV_T_x', 'GR_SQFT_x', 'NEW_FV_T_x', 'CUR_FV_T_perSQFT_x',
#        'NEW_FV_T_perSQFT_x', 'CUR_FV_T_y', 'GR_SQFT_y', 'NEW_FV_T_y',
#        'CUR_FV_T_perSQFT_y', 'NEW_FV_T_perSQFT_y', 'Median_house_Value',
#        'Median_Rent', 'Total_pop', 'Pop_Den', 'Median_Household_Income',
#        'Ratio_income_to_poverty_level_under_2', 'Gini_Index',
#        'Ave_Commute_Min', 'Dropout_16_19', 'Bachelor_up_25_64',
#        'Unemployed_rate_16', 'Occupied_Housing_Units_2015_',
#        'Occupied_Housing_Units_2010_2014',
#        'Occupied_Housing_Units_2010_before'],
#       dtype='object')

# %%
def norm(data,columns):
    for x in columns:
        data[x] = (data[x]-np.min(data[x]))/(np.max(data[x])-np.min(data[x]))
    return data

# %%
data = norm(data,data.columns[9:38])

# %%
data.head(1)
# Out:
#         GEO_ID STATE COUNTY  TRACT NAME   LSAD  CENSUSAREA  \
# 0  36047010400    36    047  10400  104  Tract       0.059
#
#                                             geometry        GEOID  \
# 0  POLYGON ((-74.01115399999999 40.637404, -74.01...  36047010400
#
#    pickups_intract  NYPDviolation  NYPDmisdemeanor  NYPDfelony  units  \
# 0         0.019185       0.116564         0.119454    0.111732    0.0
#
#    CUR_FV_T_x  GR_SQFT_x  NEW_FV_T_x  CUR_FV_T_perSQFT_x  NEW_FV_T_perSQFT_x  \
# 0    0.193199   0.271413    0.176446             0.24226            0.207946
#
#    CUR_FV_T_y  GR_SQFT_y  NEW_FV_T_y  CUR_FV_T_perSQFT_y  NEW_FV_T_perSQFT_y  \
# 0    0.001892   0.000849    0.002017            0.123972            0.139467
#
#    Median_house_Value  Median_Rent  Total_pop   Pop_Den  \
# 0            0.429028     0.294493   0.665285  0.621602
#
#    Median_Household_Income  Ratio_income_to_poverty_level_under_2  Gini_Index  \
# 0                 0.141055                               0.509002    0.419984
#
#    Ave_Commute_Min  Dropout_16_19  Bachelor_up_25_64  Unemployed_rate_16  \
# 0         0.403846            0.0           0.163219            0.175398
#
#    Occupied_Housing_Units_2015_  Occupied_Housing_Units_2010_2014  \
# 0                      0.061389                          0.384504
#
#    Occupied_Housing_Units_2010_before   Borough  2010CensusTract  PUMA  \
# 0                            0.640285  Brooklyn            10400  4012
#
#   NTA_Code          NTA_Name
# 0     BK34  Sunset Park East

# %% [markdown]
# ## Outliers

# %%
def clean(data,columns):
    for x in columns:
        #data= data[(np.abs(data[x]-np.median(data[x]))/(np.median(np.abs(data[x]-np.median(data[x])))/0.6745)) < 2.24]
        data = data[(data[x]<np.mean(data[x])+4*np.std(data[x]))&(data[x]>np.mean(data[x])-4*np.std(data[x]))]
    return data

# %%
data = clean(data,data.columns[9:38])

# %%
data.shape
# Out:
# (670, 43)

# %%
data.plot()

# %%
data.columns[9:38]
# Out:
# Index(['pickups_intract', 'NYPDviolation', 'NYPDmisdemeanor', 'NYPDfelony',
#        'units', 'CUR_FV_T_x', 'GR_SQFT_x', 'NEW_FV_T_x', 'CUR_FV_T_perSQFT_x',
#        'NEW_FV_T_perSQFT_x', 'CUR_FV_T_y', 'GR_SQFT_y', 'NEW_FV_T_y',
#        'CUR_FV_T_perSQFT_y', 'NEW_FV_T_perSQFT_y', 'Median_house_Value',
#        'Median_Rent', 'Total_pop', 'Pop_Den', 'Median_Household_Income',
#        'Ratio_income_to_poverty_level_under_2', 'Gini_Index',
#        'Ave_Commute_Min', 'Dropout_16_19', 'Bachelor_up_25_64',
#        'Unemployed_rate_16', 'Occupied_Housing_Units_2015_',
#        'Occupied_Housing_Units_2010_2014',
#        'Occupied_Housing_Units_2010_before'],
#       dtype='object')

# %% [markdown]
# ## PCA

# %%
X_num = data[data.columns[9:38]].drop(['units','CUR_FV_T_x','GR_SQFT_x','NEW_FV_T_x','CUR_FV_T_perSQFT_x','NEW_FV_T_perSQFT_x','CUR_FV_T_y',
                                       'GR_SQFT_y', 'NEW_FV_T_y',
       'CUR_FV_T_perSQFT_y', 'NEW_FV_T_perSQFT_y','Dropout_16_19','Occupied_Housing_Units_2015_','Occupied_Housing_Units_2010_2014',
       'Occupied_Housing_Units_2010_before','Median_house_Value'],axis=1)
pca = PCA(0.90)
Xproj = pca.fit_transform(X_num)

# %%
pca.explained_variance_ratio_
# Out:
# array([ 0.403698  ,  0.19686629,  0.12870752,  0.09003671,  0.06320803,
#         0.03176935])

# %%
components_explanation = pd.DataFrame(pca.components_,columns = X_num.columns)
components_explanation
# Out:
#    pickups_intract  NYPDviolation  NYPDmisdemeanor  NYPDfelony  Median_Rent  \
# 0        -0.008631       0.272614         0.137955    0.134230    -0.194991
# 1        -0.123750       0.001822        -0.013039   -0.013481    -0.189112
# 2         0.035630      -0.005201         0.021720    0.023190    -0.093653
# 3         0.172029       0.655380         0.353953    0.355835    -0.016723
# 4         0.190078       0.162725         0.161459    0.162952     0.190074
# 5         0.033396       0.154280         0.043104    0.044895    -0.132749
#
#    Total_pop   Pop_Den  Median_Household_Income  \
# 0   0.401216  0.344337                -0.294116
# 1  -0.468876 -0.357306                -0.155332
# 2  -0.211555 -0.224515                -0.189817
# 3  -0.001435 -0.240836                 0.080656
# 4  -0.056433 -0.285404                 0.007455
# 5  -0.488013  0.700700                -0.085059
#
#    Ratio_income_to_poverty_level_under_2  Gini_Index  Ave_Commute_Min  \
# 0                               0.457168    0.146899         0.044976
# 1                              -0.204280   -0.142208         0.268882
# 2                              -0.028707    0.885475        -0.258656
# 3                              -0.152042   -0.013542         0.298444
# 4                               0.122443   -0.286835        -0.785506
# 5                              -0.282025   -0.074979        -0.250016
#
#    Bachelor_up_25_64  Unemployed_rate_16
# 0          -0.489991            0.108604
# 1          -0.659103            0.090883
# 2           0.055854            0.053078
# 3           0.271347            0.195434
# 4          -0.209988           -0.074584
# 5           0.054986            0.257919

# %% [markdown]
# ## FA

# %%
fa = FactorAnalyzer()

# %%
fa.analyze(X_num,5,rotation='varimax')

# %%
fa.get_communalities()
# Out:
#                                        Communalities
# pickups_intract                             0.431024
# NYPDviolation                               0.774616
# NYPDmisdemeanor                             0.968596
# NYPDfelony                                  0.955617
# Median_Rent                                 0.597472
# Total_pop                                   0.931643
# Pop_Den                                     0.604007
# Median_Household_Income                     0.862161
# Ratio_income_to_poverty_level_under_2       0.946540
# Gini_Index                                  0.470959
# Ave_Commute_Min                             0.600980
# Bachelor_up_25_64                           0.812638
# Unemployed_rate_16                          0.315253

# %%
fa.loadings
# Out:
#                                         Factor1   Factor2   Factor3   Factor4  \
# pickups_intract                       -0.408751  0.393258 -0.051829  0.086954
# NYPDviolation                         -0.805184 -0.173269 -0.245208  0.083849
# NYPDmisdemeanor                       -0.958877 -0.137665 -0.166683  0.047624
# NYPDfelony                            -0.955437 -0.127031 -0.154374  0.050434
# Median_Rent                            0.157991  0.613896  0.126246 -0.285895
# Total_pop                             -0.234388  0.016610 -0.935267  0.039870
# Pop_Den                               -0.069668 -0.108880 -0.763861  0.053786
# Median_Household_Income                0.225276  0.761590  0.274137 -0.395050
# Ratio_income_to_poverty_level_under_2 -0.252694 -0.413516 -0.816713  0.130135
# Gini_Index                            -0.080788 -0.100697 -0.075065  0.654060
# Ave_Commute_Min                       -0.071080 -0.171015  0.062560 -0.173971
# Bachelor_up_25_64                      0.160409  0.866843  0.117735  0.086397
# Unemployed_rate_16                    -0.366460 -0.267180 -0.044158  0.207298
#
#                                         Factor5
# pickups_intract                       -0.314719
# NYPDviolation                          0.170633
# NYPDmisdemeanor                       -0.012142
# NYPDfelony                            -0.015662
# Median_Rent                           -0.313000
# Total_pop                             -0.010787
# Pop_Den                                0.030378
# Median_Household_Income               -0.013280
# Ratio_income_to_poverty_level_under_2 -0.166536
# Gini_Index                            -0.144441
# Ave_Commute_Min                        0.729727
# Bachelor_up_25_64                     -0.119015
# Unemployed_rate_16                     0.254270

# %%
fa.get_factor_variance()
# Out:
#                  Factor1   Factor2   Factor3   Factor4   Factor5
# SS Loadings     3.018662  2.221963  2.356104  0.787119  0.887657
# Proportion Var  0.232205  0.170920  0.181239  0.060548  0.068281
# Cumulative Var  0.232205  0.403125  0.584364  0.644911  0.713193

# %%
fa.loadings[np.abs(fa.loadings['Factor1'])>0.5]['Factor1']
# Out:
# NYPDviolation     -0.805184
# NYPDmisdemeanor   -0.958877
# NYPDfelony        -0.955437
# Name: Factor1, dtype: float64

# %%
for column in fa.loadings:
    print(column+':\n')
    print(fa.loadings[np.abs(fa.loadings[column])>0.5][column])
    print('\n')
# Out:
# Factor1:
#
# NYPDviolation     -0.805184
# NYPDmisdemeanor   -0.958877
# NYPDfelony        -0.955437
# Name: Factor1, dtype: float64
#
#
# Factor2:
#
# Median_Rent                0.613896
# Median_Household_Income    0.761590
# Bachelor_up_25_64          0.866843
# Name: Factor2, dtype: float64
#
#
# Factor3:
#
# Total_pop                               -0.935267
# Pop_Den                                 -0.763861
# Ratio_income_to_poverty_level_under_2   -0.816713
# Name: Factor3, dtype: float64
#
#
# Factor4:
#
# Gini_Index    0.65406
# Name: Factor4, dtype: float64
#
#
# Factor5:
#
# Ave_Commute_Min    0.729727
# Name: Factor5, dtype: float64

# %% [markdown]
# ## Factor 1: Crime and human traffic
# ## Factor 2: Education and income level
# ## Factor 3: Population and poverty level
# ## Factor 4: Income integration and commute efficiency

# %%
X_num.head(1)
# Out:
#    pickups_intract  NYPDviolation  NYPDmisdemeanor  NYPDfelony  Median_Rent  \
# 0         0.019185       0.116564         0.119454    0.111732     0.294493
#
#    Total_pop   Pop_Den  Median_Household_Income  \
# 0   0.665285  0.621602                 0.141055
#
#    Ratio_income_to_poverty_level_under_2  Gini_Index  Ave_Commute_Min  \
# 0                               0.509002    0.419984         0.403846
#
#    Bachelor_up_25_64  Unemployed_rate_16
# 0           0.163219            0.175398

# %%
X_num.to_csv('X_num.csv')

# %%
X_num1 = pd.read_csv('X_num1.csv')

# %%
data = data.drop(list(X_num.columns)+['Dropout_16_19','Occupied_Housing_Units_2015_','Occupied_Housing_Units_2010_2014',
       'Occupied_Housing_Units_2010_before','Median_house_Value'],axis=1)

# %%
data.head(1)
# Out:
#         GEO_ID STATE COUNTY  TRACT NAME   LSAD  CENSUSAREA  \
# 0  36047010400    36    047  10400  104  Tract       0.059
#
#                                             geometry        GEOID  units  \
# 0  POLYGON ((-74.01115399999999 40.637404, -74.01...  36047010400    0.0
#
#    CUR_FV_T_x  GR_SQFT_x  NEW_FV_T_x  CUR_FV_T_perSQFT_x  NEW_FV_T_perSQFT_x  \
# 0    0.193199   0.271413    0.176446             0.24226            0.207946
#
#    CUR_FV_T_y  GR_SQFT_y  NEW_FV_T_y  CUR_FV_T_perSQFT_y  NEW_FV_T_perSQFT_y  \
# 0    0.001892   0.000849    0.002017            0.123972            0.139467
#
#     Borough  2010CensusTract  PUMA NTA_Code          NTA_Name
# 0  Brooklyn            10400  4012     BK34  Sunset Park East

# %%
X_num1 = X_num1[X_num1.columns[-4:]]

# %%
X_num1.columns = ['Crime and human traffic','Education and income level','Population and poverty level','Income integration and commute efficiency']

# %%
for column in X_num1.columns:
    data[column] = X_num1[column]

# %%
columns = []
for column in data.columns:
    column = column.replace(' ','_' )
    columns.append(column)

# %%
data.columns = columns

# %%
data.head(1)
# Out:
#         GEO_ID STATE COUNTY  TRACT NAME   LSAD  CENSUSAREA  \
# 0  36047010400    36    047  10400  104  Tract       0.059
#
#                                             geometry        GEOID  units  \
# 0  POLYGON ((-74.01115399999999 40.637404, -74.01...  36047010400    0.0
#
#    CUR_FV_T_x  GR_SQFT_x  NEW_FV_T_x  CUR_FV_T_perSQFT_x  NEW_FV_T_perSQFT_x  \
# 0    0.193199   0.271413    0.176446             0.24226            0.207946
#
#    CUR_FV_T_y  GR_SQFT_y  NEW_FV_T_y  CUR_FV_T_perSQFT_y  NEW_FV_T_perSQFT_y  \
# 0    0.001892   0.000849    0.002017            0.123972            0.139467
#
#     Borough  2010CensusTract  PUMA NTA_Code          NTA_Name  \
# 0  Brooklyn            10400  4012     BK34  Sunset Park East
#
#    Crime_and_human_traffic  Education_and_income_level  \
# 0                -0.453501                   -0.582911
#
#    Population_and_poverty_level  Income_integration_and_commute_efficiency
# 0                      2.430752                                  -0.072337

# %%
data.units[data.units > 0] =1
# Out:
# C:\Users\sddz0\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
'NEW_FV_T_perSQFT_x~'+'+'.join(data.columns[-4:])
# Out:
# 'NEW_FV_T_perSQFT_x~Crime_and_human_traffic+Education_and_income_level+Population_and_poverty_level+Income_integration_and_commute_efficiency'

# %%
data['difference'] = data['NEW_FV_T_perSQFT_x'] - data['CUR_FV_T_perSQFT_x']

# %%
data['difference1'] = data['NEW_FV_T_perSQFT_y'] - data['CUR_FV_T_perSQFT_y']

# %%
lm_no_units = smf.ols(formula='difference~'+'+'.join(data.columns[-6:-2])
             ,data=data).fit()
lm_no_units.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             difference   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     2.648
# Date:                Fri, 08 Dec 2017   Prob (F-statistic):             0.0326
# Time:                        15:42:36   Log-Likelihood:                 1509.1
# No. Observations:                 583   AIC:                            -3008.
# Df Residuals:                     578   BIC:                            -2986.
# Df Model:                           4
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Intercept                                    -0.0013      0.001     -1.691      0.091      -0.003       0.000
# Crime_and_human_traffic                      -0.0003      0.001     -0.406      0.685      -0.002       0.001
# Education_and_income_level                   -0.0004      0.001     -0.506      0.613      -0.002       0.001
# Population_and_poverty_level                 -0.0010      0.001     -1.322      0.187      -0.003       0.000
# Income_integration_and_commute_efficiency     0.0022      0.001      2.873      0.004       0.001       0.004
# ==============================================================================
# Omnibus:                       18.341   Durbin-Watson:                   1.573
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.278
# Skew:                          -0.417   Prob(JB):                     6.52e-05
# Kurtosis:                       3.311   Cond. No.                         1.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm_with_units = smf.ols(formula='difference~C(units)+'+'+'.join(data.columns[-6:-2])
             ,data=data).fit()
lm_with_units.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             difference   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     3.437
# Date:                Fri, 08 Dec 2017   Prob (F-statistic):            0.00454
# Time:                        15:42:37   Log-Likelihood:                 1512.4
# No. Observations:                 583   AIC:                            -3013.
# Df Residuals:                     577   BIC:                            -2986.
# Df Model:                           5
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Intercept                                    -0.0016      0.001     -2.097      0.036      -0.003      -0.000
# C(units)[T.1.0]                               0.0118      0.005      2.548      0.011       0.003       0.021
# Crime_and_human_traffic                      -0.0002      0.001     -0.282      0.778      -0.002       0.001
# Education_and_income_level                   -0.0004      0.001     -0.508      0.612      -0.002       0.001
# Population_and_poverty_level                 -0.0009      0.001     -1.210      0.227      -0.002       0.001
# Income_integration_and_commute_efficiency     0.0022      0.001      2.937      0.003       0.001       0.004
# ==============================================================================
# Omnibus:                       19.461   Durbin-Watson:                   1.570
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.783
# Skew:                          -0.420   Prob(JB):                     3.07e-05
# Kurtosis:                       3.388   Cond. No.                         6.33
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
anova = sm.stats.anova_lm(lm_no_units,lm_with_units)
anova
# Out:
# C:\Users\sddz0\Anaconda2\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\sddz0\Anaconda2\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\sddz0\Anaconda2\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#    df_resid       ssr  df_diff   ss_diff         F    Pr(>F)
# 0     578.0  0.192688      0.0       NaN       NaN       NaN
# 1     577.0  0.190545      1.0  0.002143  6.490632  0.011103

# %%
lm1_no_units = smf.ols(formula='difference1~'+'+'.join(data.columns[-5:-1])
             ,data=data).fit()
lm1_no_units.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            difference1   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     10.61
# Date:                Fri, 08 Dec 2017   Prob (F-statistic):           2.64e-08
# Time:                        15:42:38   Log-Likelihood:                 1466.0
# No. Observations:                 583   AIC:                            -2922.
# Df Residuals:                     578   BIC:                            -2900.
# Df Model:                           4
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Intercept                                     0.0144      0.001     17.579      0.000       0.013       0.016
# Education_and_income_level                   -0.0013      0.001     -1.602      0.110      -0.003       0.000
# Population_and_poverty_level                  0.0005      0.001      0.632      0.528      -0.001       0.002
# Income_integration_and_commute_efficiency     0.0003      0.001      0.416      0.678      -0.001       0.002
# difference                                    0.2761      0.045      6.166      0.000       0.188       0.364
# ==============================================================================
# Omnibus:                       41.600   Durbin-Watson:                   1.389
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.850
# Skew:                           0.550   Prob(JB):                     1.01e-13
# Kurtosis:                       4.121   Cond. No.                         56.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lm1_with_units = smf.ols(formula='difference1~C(units)+'+'+'.join(data.columns[-5:-1])
             ,data=data).fit()
lm1_with_units.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            difference1   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     8.505
# Date:                Fri, 08 Dec 2017   Prob (F-statistic):           8.80e-08
# Time:                        15:42:38   Log-Likelihood:                 1466.1
# No. Observations:                 583   AIC:                            -2920.
# Df Residuals:                     577   BIC:                            -2894.
# Df Model:                           5
# Covariance Type:            nonrobust
# =============================================================================================================
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# Intercept                                     0.0143      0.001     17.237      0.000       0.013       0.016
# C(units)[T.1.0]                               0.0019      0.005      0.372      0.710      -0.008       0.012
# Education_and_income_level                   -0.0013      0.001     -1.601      0.110      -0.003       0.000
# Population_and_poverty_level                  0.0005      0.001      0.646      0.519      -0.001       0.002
# Income_integration_and_commute_efficiency     0.0003      0.001      0.427      0.670      -0.001       0.002
# difference                                    0.2743      0.045      6.087      0.000       0.186       0.363
# ==============================================================================
# Omnibus:                       41.898   Durbin-Watson:                   1.392
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.469
# Skew:                           0.551   Prob(JB):                     7.40e-14
# Kurtosis:                       4.128   Cond. No.                         56.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
anova = sm.stats.anova_lm(lm1_no_units,lm1_with_units)
anova
# Out:
# C:\Users\sddz0\Anaconda2\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\sddz0\Anaconda2\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\sddz0\Anaconda2\envs\py36\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#    df_resid       ssr  df_diff   ss_diff        F    Pr(>F)
# 0     578.0  0.223355      0.0       NaN      NaN       NaN
# 1     577.0  0.223301      1.0  0.000053  0.13812  0.710293

# %% [markdown]
# ## Spatial regression

# %%
W = pysal.weights.Queen.from_dataframe(data)
# Out:
# C:\Users\sddz0\Anaconda2\envs\py36\lib\site-packages\pysal\weights\weights.py:189: UserWarning: There are 3 disconnected observations
#   warnings.warn("There are %d disconnected observations" % ni)
# C:\Users\sddz0\Anaconda2\envs\py36\lib\site-packages\pysal\weights\weights.py:190: UserWarning: Island ids: 75, 192, 549
#   warnings.warn("Island ids: %s" % ', '.join(str(island) for island in self.islands))

# %%
W.islands
# Out:
# [75, 192, 549]

# %%
W[768]
# Out:
# {175: 1.0, 645: 1.0, 649: 1.0, 650: 1.0, 652: 1.0}

# %%
data.shape
# Out:
# (670, 31)

# %%
data = data.drop(W.islands)

# %%
W1 = pysal.weights.Queen.from_dataframe(data)

# %%
pysal.Moran(ls.u, w, two_tailed=False)
